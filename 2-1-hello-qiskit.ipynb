# %%
# %pip install qiskit
# %pip install pylatexenc
# Out:
# Requirement already satisfied: qiskit in /opt/homebrew/lib/python3.11/site-packages (0.42.1)
# Requirement already satisfied: qiskit-terra==0.23.3 in /opt/homebrew/lib/python3.11/site-packages (from qiskit) (0.23.3)
# Requirement already satisfied: qiskit-aer==0.12.0 in /opt/homebrew/lib/python3.11/site-packages (from qiskit) (0.12.0)
# Requirement already satisfied: qiskit-ibmq-provider==0.20.2 in /opt/homebrew/lib/python3.11/site-packages (from qiskit) (0.20.2)
# Requirement already satisfied: numpy>=1.16.3 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-aer==0.12.0->qiskit) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-aer==0.12.0->qiskit) (1.10.1)
# Requirement already satisfied: requests>=2.19 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (2.29.0)
# Requirement already satisfied: requests-ntlm<=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.1.0)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.26.15)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.5.1)
# Requirement already satisfied: websockets>=10.0 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (11.0.2)
# Requirement already satisfied: rustworkx>=0.12.0 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-terra==0.23.3->qiskit) (0.12.1)
# Requirement already satisfied: ply>=3.10 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-terra==0.23.3->qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-terra==0.23.3->qiskit) (5.9.5)
# Requirement already satisfied: sympy>=1.3 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-terra==0.23.3->qiskit) (1.11.1)
# Requirement already satisfied: dill>=0.3 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-terra==0.23.3->qiskit) (0.3.6)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-terra==0.23.3->qiskit) (5.0.0)
# Requirement already satisfied: symengine>=0.9 in /opt/homebrew/lib/python3.11/site-packages (from qiskit-terra==0.23.3->qiskit) (0.9.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (2022.12.7)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /opt/homebrew/lib/python3.11/site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in /opt/homebrew/lib/python3.11/site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (40.0.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit-terra==0.23.3->qiskit) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy>=1.3->qiskit-terra==0.23.3->qiskit) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /opt/homebrew/lib/python3.11/site-packages (from cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.15.1)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pylatexenc in /opt/homebrew/lib/python3.11/site-packages (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
# https://www.youtube.com/watch?v=yGzmA98D0eU
import qiskit as q

#check qiskit version
print(q.__qiskit_version__)
# Out:
# {'qiskit-terra': '0.23.3', 'qiskit-aer': '0.12.0', 'qiskit-ignis': None, 'qiskit-ibmq-provider': '0.20.2', 'qiskit': '0.42.1', 'qiskit-nature': None, 'qiskit-finance': None, 'qiskit-optimization': None, 'qiskit-machine-learning': None}

# %%
# here we use a quantum computer simulator - with no access to underlying vectors
# init quantum computer simulator
simulator = q.Aer.get_backend('qasm_simulator')

# %%
# init circuit
circuit = q.QuantumCircuit(1,1) #qbits, classic measure bits

# build circuit
#  add hadamard gate on line 0
circuit.h(0)
#  add measure of qbit line 0 to classic line 0 - to enable counts
circuit.measure(0,0)

# %%
# display circuit, text based
print(circuit.draw('text'))
# graphical
circuit.draw('mpl')
# Out:
#      ┌───┐┌─┐
#   q: ┤ H ├┤M├
#      └───┘└╥┘
# c: 1/══════╩═
#            0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# run circuit on simulator
job = q.execute(circuit, simulator, shots=1000)

# wait for results
result = job.result()

# count measures
counts = result.get_counts(circuit)
print(f"Nombre de 0 et 1:{counts}")
# Out:
# Nombre de 0 et 1:{'0': 499, '1': 501}

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
# display results
q.visualization.plot_histogram(counts)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
